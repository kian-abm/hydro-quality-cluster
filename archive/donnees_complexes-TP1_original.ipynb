# %%
import pandas as pd

# %% [markdown]
# # Étude préliminaire

# %% [markdown]
# ## Chargement

# %%
analyse_file = "analyses_2022.csv.zst"

analyse_df_sample = pd.read_csv(analyse_file, sep=";", nrows=1)

categorical_values = ("Lb", "Nom", "Mnemo", "Cd", "Sym", "Com")
categories = analyse_df_sample.columns[analyse_df_sample.columns.str.startswith(categorical_values)]

dict_categories = {col: "category" for col in categories}
dict_converters = {col: str for col in categories}
chunksize = 500_000

iterator = pd.read_csv(analyse_file, 
                       sep=";", 
                       na_values="",
                       escapechar="\\",
                       converters=dict_converters,
                       dtype = {'RsAna':'str'},
                       parse_dates=['DatePrel'],
                       chunksize=chunksize)
iterator

analyse_df = None
i=0
for df in iterator:
    print(i)
    i+=chunksize
    df = df.astype(dtype=dict_categories)
    #on enlève la teinte de l'eau (1739) et l'odeur (1416) qui donnent un résultat en chaine de caractère
    cond_remove_teinte = df.CdParametre!='1739'
    cond_remove_odeur = df.CdParametre!='1416'
    df = df[cond_remove_teinte & cond_remove_odeur].astype({'RsAna':'float64'})
    if analyse_df is None:
        analyse_df = df
    else:
        for col in dict_categories:
            cat_union = analyse_df[col].cat.categories.union(df[col].cat.categories);
            analyse_df[col]=analyse_df[col].cat.set_categories(cat_union)
            df[col]=df[col].cat.set_categories(cat_union)
        analyse_df= pd.concat([analyse_df,df],ignore_index=True)

analyse_df
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# /tmp/ipykernel_120010/1606182481.py:24: DtypeWarning: Columns (0: HeureAna) have mixed types. Specify dtype option on import or set low_memory=False.
#   for df in iterator:
# 6500000
# /tmp/ipykernel_120010/1606182481.py:24: DtypeWarning: Columns (0: HeureAna) have mixed types. Specify dtype option on import or set low_memory=False.
#   for df in iterator:
# 7000000
# /tmp/ipykernel_120010/1606182481.py:24: DtypeWarning: Columns (0: HeureAna) have mixed types. Specify dtype option on import or set low_memory=False.
#   for df in iterator:
# 7500000
# /tmp/ipykernel_120010/1606182481.py:24: DtypeWarning: Columns (0: HeureAna) have mixed types. Specify dtype option on import or set low_memory=False.
#   for df in iterator:
# 8000000
# 8500000
#         CdStationMesureEauxSurface  \
# 0                         01002237
# 1                         01002237
# 2                         01002237
# 3                         01002237
# 4                         01002237
# ...                            ...
# 8790163                   06133330
# 8790164                   06133330
# 8790165                   06133330
# 8790166                   06133330
# 8790167                   06133330
#
#                                 LbStationMesureEauxSurface CdSupport  \
# 0        HEM ET MEULESTROM A TOURNEHEM SUR LA HEM (62) [3]         3
# 1        HEM ET MEULESTROM A TOURNEHEM SUR LA HEM (62) [3]         3
# 2        HEM ET MEULESTROM A TOURNEHEM SUR LA HEM (62) [3]         3
# 3        HEM ET MEULESTROM A TOURNEHEM SUR LA HEM (62) [3]         3
# 4        HEM ET MEULESTROM A TOURNEHEM SUR LA HEM (62) [3]         3
# ...                                                    ...       ...
# 8790163        DORON DE CHAMPAGNY A CHAMPAGNY-EN-VANOISE 2         3
# 8790164        DORON DE CHAMPAGNY A CHAMPAGNY-EN-VANOISE 2         3
# 8790165        DORON DE CHAMPAGNY A CHAMPAGNY-EN-VANOISE 2         3
# 8790166        DORON DE CHAMPAGNY A CHAMPAGNY-EN-VANOISE 2         3
# 8790167        DORON DE CHAMPAGNY A CHAMPAGNY-EN-VANOISE 2         3
#
#         LbSupport CdFractionAnalysee  \
# 0             Eau                 23
# 1             Eau                 23
# 2             Eau                 23
# 3             Eau                 23
# 4             Eau                 23
# ...           ...                ...
# 8790163       Eau                  3
# 8790164       Eau                  3
# 8790165       Eau                  3
# 8790166       Eau                  3
# 8790167       Eau                  3
#
#                                        LbFractionAnalysee  \
# 0                                               Eau brute
# 1                                               Eau brute
# 2                                               Eau brute
# 3                                               Eau brute
# 4                                               Eau brute
# ...                                                   ...
# 8790163  Phase aqueuse de l'eau (filtrée, centrifugée...)
# 8790164  Phase aqueuse de l'eau (filtrée, centrifugée...)
# 8790165  Phase aqueuse de l'eau (filtrée, centrifugée...)
# 8790166  Phase aqueuse de l'eau (filtrée, centrifugée...)
# 8790167  Phase aqueuse de l'eau (filtrée, centrifugée...)
#
#                       CdPrelevement   DatePrel HeurePrel     DateAna  ...  \
# 0        01002237202204061010222223 2022-04-06  10:10:00         NaN  ...
# 1        01002237202204061010222223 2022-04-06  10:10:00         NaN  ...
# 2        01002237202204061010222223 2022-04-06  10:10:00         NaN  ...
# 3        01002237202204061010222223 2022-04-06  10:10:00         NaN  ...
# 4        01002237202204061010222223 2022-04-06  10:10:00         NaN  ...
# ...                             ...        ...       ...         ...  ...
# 8790163                      778243 2022-10-25  15:22:00  2022-10-26  ...
# 8790164                      778243 2022-10-25  15:22:00  2022-10-26  ...
# 8790165                      778243 2022-10-25  15:22:00  2022-10-26  ...
# 8790166                      778243 2022-10-25  15:22:00  2022-10-26  ...
# 8790167                      778243 2022-10-25  15:22:00  2022-10-26  ...
#
#         CommentairesAna ComResultatAna                  CdRdd  \
# 0                                                  0101320161
# 1                                                  0101320161
# 2                                                  0101320161
# 3                                                  0101320161
# 4                                                  0101320161
# ...                 ...            ...                    ...
# 8790163                                 0600000261/0600000275
# 8790164                                 0600000261/0600000275
# 8790165                                 0600000261/0600000275
# 8790166                                 0600000261/0600000275
# 8790167                                 0600000261/0600000275
#
#                                                     NomRdd    CdProducteur  \
# 0        Réseau de suivi local de l’opération de restau...  18591178100028
# 1        Réseau de suivi local de l’opération de restau...  18591178100028
# 2        Réseau de suivi local de l’opération de restau...  18591178100028
# 3        Réseau de suivi local de l’opération de restau...  18591178100028
# 4        Réseau de suivi local de l’opération de restau...  18591178100028
# ...                                                    ...             ...
# 8790163                                                     18690155900069
# 8790164                                                     18690155900069
# 8790165                                                     18690155900069
# 8790166                                                     18690155900069
# 8790167                                                     18690155900069
#
#                                   NomProducteur     CdPreleveur  \
# 0               AGENCE DE L EAU ARTOIS PICARDIE  41054531300042
# 1               AGENCE DE L EAU ARTOIS PICARDIE  41054531300042
# 2               AGENCE DE L EAU ARTOIS PICARDIE  41054531300042
# 3               AGENCE DE L EAU ARTOIS PICARDIE  41054531300042
# 4               AGENCE DE L EAU ARTOIS PICARDIE  41054531300042
# ...                                         ...             ...
# 8790163  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 8790164  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 8790165  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 8790166  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 8790167  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
#
#                                               NomPreleveur   CdLaboratoire  \
# 0        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 1        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 2        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 3        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 4        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# ...                                                    ...             ...
# 8790163  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 8790164  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 8790165  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 8790166  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 8790167  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
#
#                                             NomLaboratoire
# 0        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 1        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 2        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 3        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 4        CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# ...                                                    ...
# 8790163  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 8790164  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 8790165  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 8790166  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 8790167  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
#
# [8790168 rows x 51 columns]

# %% [markdown]
# ## Étude des données brutes

# %% [markdown]
# ### Sélection des informations utiles
#
# Quelles colonnes garder ?
#
# - Colonnes suffisamment complètes
# - Colonnes en lien avec notre objectif : on cherche à analyser les **résultats d'analyse** par **Station** et **Prélèvement** (par **date**). Un résultat se caractérise par une **valeur**, un **paramètre physico-chimique**, une **fraction** et une **unité de mesure**

# %%
analyse_df.info(show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790168 entries, 0 to 8790167
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   CdStationMesureEauxSurface  8790168 non-null  category
#  1   LbStationMesureEauxSurface  8790168 non-null  category
#  2   CdSupport                   8790168 non-null  category
#  3   LbSupport                   8790168 non-null  category
#  4   CdFractionAnalysee          8790168 non-null  category
#  5   LbFractionAnalysee          8790168 non-null  category
#  6   CdPrelevement               8790168 non-null  category
#  7   DatePrel                    8790168 non-null  datetime64[us]
#  8   HeurePrel                   8790168 non-null  str
#  9   DateAna                     8307222 non-null  str
#  10  HeureAna                    5774832 non-null  object
#  11  CdParametre                 8790168 non-null  category
#  12  LbLongParamètre             8790168 non-null  category
#  13  RsAna                       8298011 non-null  float64
#  14  CdUniteMesure               8790168 non-null  category
#  15  SymUniteMesure              8790168 non-null  category
#  16  CdRqAna                     8790168 non-null  category
#  17  MnemoRqAna                  8790168 non-null  category
#  18  CdInsituAna                 8790168 non-null  category
#  19  LbInsituAna                 8790168 non-null  category
#  20  ProfondeurPrel              189784 non-null   float64
#  21  CdDifficulteAna             8790168 non-null  category
#  22  MnemoDifficulteAna          8790168 non-null  category
#  23  LdAna                       7881188 non-null  float64
#  24  LqAna                       8306880 non-null  float64
#  25  LsAna                       345 non-null      float64
#  26  IncertAna                   7935408 non-null  float64
#  27  CdMetFractionnement         8790168 non-null  category
#  28  NomMetFractionnement        8790168 non-null  category
#  29  CdMethode                   8790168 non-null  category
#  30  NomMethode                  8790168 non-null  category
#  31  RdtExtraction               2939667 non-null  float64
#  32  CdMethodeExtraction         8790168 non-null  category
#  33  NomMethodeExtraction        8790168 non-null  category
#  34  CdAccreAna                  8790168 non-null  category
#  35  MnemoAccredAna              8790168 non-null  category
#  36  AgreAna                     7094900 non-null  float64
#  37  CdStatutAna                 8790168 non-null  category
#  38  MnemoStatutAna              8790168 non-null  category
#  39  CdQualAna                   8790168 non-null  category
#  40  LbQualAna                   8790168 non-null  category
#  41  CommentairesAna             8790168 non-null  category
#  42  ComResultatAna              8790168 non-null  category
#  43  CdRdd                       8790168 non-null  category
#  44  NomRdd                      8790168 non-null  category
#  45  CdProducteur                8790168 non-null  category
#  46  NomProducteur               8790168 non-null  category
#  47  CdPreleveur                 8790168 non-null  category
#  48  NomPreleveur                8790168 non-null  category
#  49  CdLaboratoire               8790168 non-null  category
#  50  NomLaboratoire              8790168 non-null  category
# dtypes: category(39), datetime64[us](1), float64(8), object(1), str(2)
# memory usage: 1.3+ GB

# %%
analyse_df_slim = analyse_df.iloc[:,list(range(0,8))+list(range(11,18))+[23,24]]
analyse_df_slim.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790168 entries, 0 to 8790167
# Data columns (total 17 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   CdStationMesureEauxSurface  category
#  1   LbStationMesureEauxSurface  category
#  2   CdSupport                   category
#  3   LbSupport                   category
#  4   CdFractionAnalysee          category
#  5   LbFractionAnalysee          category
#  6   CdPrelevement               category
#  7   DatePrel                    datetime64[us]
#  8   CdParametre                 category
#  9   LbLongParamètre             category
#  10  RsAna                       float64
#  11  CdUniteMesure               category
#  12  SymUniteMesure              category
#  13  CdRqAna                     category
#  14  MnemoRqAna                  category
#  15  LdAna                       float64
#  16  LqAna                       float64
# dtypes: category(13), datetime64[us](1), float64(3)
# memory usage: 421.4 MB

# %% [markdown]
# ## Statistiques descriptives

# %% [markdown]
# ### Description des différentes colonnes

# %%
analyse_df_slim.describe()
# Out:
#                          DatePrel         RsAna         LdAna         LqAna
# count                     8790168  8.298011e+06  7.881188e+06  8.306880e+06
# mean   2022-06-03 22:34:42.573712  1.671978e+01  1.196799e+00  3.468330e+00
# min           2022-01-01 00:00:00  0.000000e+00 -2.000000e+01 -2.000000e+01
# 25%           2022-03-16 00:00:00  5.000000e-03  1.700000e-03  5.000000e-03
# 50%           2022-05-19 00:00:00  2.000000e-02  7.000000e-03  2.000000e-02
# 75%           2022-08-11 00:00:00  2.500000e-02  7.000000e-03  2.000000e-02
# max           2022-12-30 00:00:00  1.337750e+07  1.670000e+04  5.000000e+04
# std                           NaN  7.627338e+03  3.704156e+01  1.134691e+02

# %% [markdown]
# ### Description des différents paramètres physico-chimiques
# Les paramètres physico-chimiques étant très nombreux, on va tout d'abord se limiter aux plus fréquents

# %%
specif_param = analyse_df_slim['LbLongParamètre'] \
                .str.cat(analyse_df_slim['LbFractionAnalysee'],sep=' - ') \
                .str.cat(analyse_df_slim['SymUniteMesure'],sep=' - ') \
                .astype('category')

specif_param
# Out:
# 0          Turbidité Formazine Néphélométrique - Eau brut...
# 1                      Température de l'Eau - Eau brute - °C
# 2          Potentiel en Hydrogène (pH) - Eau brute - unit...
# 3                    Conductivité à 25°C - Eau brute - µS/cm
# 4                     Oxygène dissous - Eau brute - mg(O2)/L
#                                  ...
# 8790163    Titre alcalimétrique complet (T.A.C.) - Phase ...
# 8790164    Potassium - Phase aqueuse de l'eau (filtrée, c...
# 8790165    Magnésium - Phase aqueuse de l'eau (filtrée, c...
# 8790166    Calcium - Phase aqueuse de l'eau (filtrée, cen...
# 8790167    Sodium - Phase aqueuse de l'eau (filtrée, cent...
# Name: LbLongParamètre, Length: 8790168, dtype: category
# Categories (5124, str): ['1,1,1,2-Tetrachloropropane - Particule < 2 mm..., '1,1,1,2-Tetrachloropropane - Particule < 2 mm..., '1,1,1,3-Tetrachloropropane - Particule < 2 mm..., '1,1,1,3-Tetrachloropropane - Particule < 2 mm..., ..., 'tétrabromodiphényl éther (congénère 47) - Mat..., 'tétrabromodiphényl éther (congénère 47) - Par..., 'tétrabromodiphényl éther (congénère 47) - Par..., 'tétrabromodiphényl éther (congénère 47) - Pha...]

# %%
analyse_df_slim['param_frac_unit'] = specif_param

# %%
frequent_parameters = analyse_df_slim['param_frac_unit'] \
                        .groupby(analyse_df_slim['param_frac_unit']) \
                        .count() \
                        .sort_values(ascending=False) \
                        .head(30)
frequent_parameters
# Out:
# param_frac_unit
# Température de l'Eau - Eau brute - °C                                                            26468
# Potentiel en Hydrogène (pH) - Eau brute - unité pH                                               26359
# Oxygène dissous - Eau brute - mg(O2)/L                                                           26298
# Conductivité à 25°C - Eau brute - µS/cm                                                          26216
# Taux de saturation en oxygène - Eau brute - %                                                    26141
# Matières en suspension - Eau brute - mg/L                                                        22262
# Turbidité Formazine Néphélométrique - Eau brute - NFU                                            21923
# Carbone Organique - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(C)/L                   21821
# Nitrates - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO3)/L                          21734
# Phosphore total - Eau brute - mg(P)/L                                                            21667
# Azote Kjeldahl - Eau brute - mg(N)/L                                                             21662
# Orthophosphates (PO4) - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(PO4)/L             21565
# Ammonium - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NH4)/L                          21259
# Nitrites - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO2)/L                          21171
# Demande Biochimique en oxygène en 5 jours (D.B.O.5) - Eau brute - mg(O2)/L                       21054
# Demande Chimique en Oxygène (DCO) - Eau brute - mg(O2)/L                                         18102
# Titre alcalimétrique complet (T.A.C.) - Phase aqueuse de l'eau (filtrée, centrifugée...) - °f    14203
# Dureté totale - Phase aqueuse de l'eau (filtrée, centrifugée...) - °f                            14052
# Chlorophylle a - Eau brute - µg/L                                                                12741
# Pendiméthaline - Eau brute - µg/L                                                                10348
# Aldrine - Eau brute - µg/L                                                                       10300
# Endosulfan alpha - Eau brute - µg/L                                                              10291
# Hexachlorocyclohexane gamma - Eau brute - µg/L                                                   10288
# Hexachlorocyclohexane alpha - Eau brute - µg/L                                                   10288
# Endosulfan bêta - Eau brute - µg/L                                                               10288
# Chlorpyriphos-éthyl - Eau brute - µg/L                                                           10284
# Trifluraline - Eau brute - µg/L                                                                  10282
# Cyperméthrine - Eau brute - µg/L                                                                 10282
# Hexachlorobenzène - Eau brute - µg/L                                                             10280
# Heptachlore époxyde endo trans - Eau brute - µg/L                                                10277
# Name: param_frac_unit, dtype: int64

# %%
import seaborn as sns

for param in frequent_parameters.index:
    
    df_fp = analyse_df_slim[analyse_df_slim['param_frac_unit'] == param]
    g = sns.displot(
        data = df_fp,
        x = "RsAna"
        ).set(title=param)
# Out:
# /usr/lib/python3.14/site-packages/seaborn/axisgrid.py:453: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# ### Étude de la répartition par rapport aux classes de qualité

# %%
#Chargement du fichier du seq eau

seq_eau = pd.read_csv("classe_alteration_seq_eau.csv",
                      na_values="\\N",
                      true_values=['t'],
                      false_values=['f'],
                      dtype={"parametre_id" :"str",'nom':'category','nom.1':'category','libelle':'category'}).astype({'parametre_id':'category'})
seq_eau
# Out:
#          id parametre_id                   nom  alteration_id nom.1  valeur  \
# 0     10231         1301  Température de l'Eau              0  TEMP       1
# 1     10232         1301  Température de l'Eau              0  TEMP       2
# 2     10233         1301  Température de l'Eau              0  TEMP       3
# 3     10234         1301  Température de l'Eau              0  TEMP       4
# 4     10235         1301  Température de l'Eau              0  TEMP       5
# ...     ...          ...                   ...            ...   ...     ...
# 1096  10659         1383                  Zinc             16  MPMI       2
# 1097  10660         1383                  Zinc             16  MPMI       3
# 1098  10661         1383                  Zinc             16  MPMI       4
# 1099  10662         1383                  Zinc             16  MPMI       5
# 1100  10597         1389                Chrome             16  MPMI       5
#
#      libelle  borne_inf_incluse  borne_sup_incluse  borne_inf  borne_sup  \
# 0       Bleu               True              False        NaN       24.0
# 1       Vert               True              False       24.0       25.5
# 2      Jaune               True              False       25.5       27.0
# 3     Orange               True              False       27.0       28.0
# 4      Rouge               True              False       28.0        NaN
# ...      ...                ...                ...        ...        ...
# 1096    Vert               True              False        1.4       14.0
# 1097   Jaune               True              False       14.0      140.0
# 1098  Orange               True              False      140.0      330.0
# 1099   Rouge               True              False      330.0        NaN
# 1100   Rouge               True              False       50.0        NaN
#
#       unite_mesure_code
# 0                    27
# 1                    27
# 2                    27
# 3                    27
# 4                    27
# ...                 ...
# 1096                133
# 1097                133
# 1098                133
# 1099                133
# 1100                133
#
# [1101 rows x 12 columns]

# %%
analyse_merged = analyse_df_slim.merge(seq_eau,left_on="CdParametre",right_on="parametre_id")

cond_inf = analyse_merged.borne_inf.isna() | (analyse_merged.borne_inf_incluse & (analyse_merged.borne_inf <=  analyse_merged.RsAna)) | (analyse_merged.borne_inf < analyse_merged.RsAna)
cond_sup = analyse_merged.borne_sup.isna() | (analyse_merged.borne_sup_incluse & (analyse_merged.borne_sup >=  analyse_merged.RsAna)) | (analyse_merged.borne_sup > analyse_merged.RsAna)
analyse_merged = analyse_merged[cond_inf & cond_sup]

# %%
for param in frequent_parameters.index:
    
    df_fp = analyse_merged[analyse_merged['param_frac_unit'] == param]
    sns.catplot(
        data = df_fp,
        x = "valeur",
        kind = "count"
        ).set(title=param)
# Out:
# /usr/lib/python3.14/site-packages/seaborn/axisgrid.py:453: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# ### Complétion des différents paramètres physico-chimiques sur les différentes stations

# %% [markdown]
# Obtenir la liste optimale de paramètres pour le plus grand nombre de stations est complexe, on va chercher une approximation satisfaisante

# %%
parameter_frequency = analyse_df_slim['param_frac_unit'] \
                        .groupby(analyse_df_slim['param_frac_unit']) \
                        .count() \
                        .sort_values(ascending=False)
parameter_frequency.head(50)
# Out:
# param_frac_unit
# Température de l'Eau - Eau brute - °C                                                            26468
# Potentiel en Hydrogène (pH) - Eau brute - unité pH                                               26359
# Oxygène dissous - Eau brute - mg(O2)/L                                                           26298
# Conductivité à 25°C - Eau brute - µS/cm                                                          26216
# Taux de saturation en oxygène - Eau brute - %                                                    26141
# Matières en suspension - Eau brute - mg/L                                                        22262
# Turbidité Formazine Néphélométrique - Eau brute - NFU                                            21923
# Carbone Organique - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(C)/L                   21821
# Nitrates - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO3)/L                          21734
# Phosphore total - Eau brute - mg(P)/L                                                            21667
# Azote Kjeldahl - Eau brute - mg(N)/L                                                             21662
# Orthophosphates (PO4) - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(PO4)/L             21565
# Ammonium - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NH4)/L                          21259
# Nitrites - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO2)/L                          21171
# Demande Biochimique en oxygène en 5 jours (D.B.O.5) - Eau brute - mg(O2)/L                       21054
# Demande Chimique en Oxygène (DCO) - Eau brute - mg(O2)/L                                         18102
# Titre alcalimétrique complet (T.A.C.) - Phase aqueuse de l'eau (filtrée, centrifugée...) - °f    14203
# Dureté totale - Phase aqueuse de l'eau (filtrée, centrifugée...) - °f                            14052
# Chlorophylle a - Eau brute - µg/L                                                                12741
# Pendiméthaline - Eau brute - µg/L                                                                10348
# Aldrine - Eau brute - µg/L                                                                       10300
# Endosulfan alpha - Eau brute - µg/L                                                              10291
# Hexachlorocyclohexane gamma - Eau brute - µg/L                                                   10288
# Hexachlorocyclohexane alpha - Eau brute - µg/L                                                   10288
# Endosulfan bêta - Eau brute - µg/L                                                               10288
# Chlorpyriphos-éthyl - Eau brute - µg/L                                                           10284
# Trifluraline - Eau brute - µg/L                                                                  10282
# Cyperméthrine - Eau brute - µg/L                                                                 10282
# Hexachlorobenzène - Eau brute - µg/L                                                             10280
# Heptachlore époxyde endo trans - Eau brute - µg/L                                                10277
# Heptachlore époxyde exo cis - Eau brute - µg/L                                                   10277
# Heptachlore - Eau brute - µg/L                                                                   10276
# DDD 44' - Eau brute - µg/L                                                                       10275
# DDE 44' - Eau brute - µg/L                                                                       10275
# Dieldrine - Eau brute - µg/L                                                                     10275
# Isodrine - Eau brute - µg/L                                                                      10275
# Atrazine - Eau brute - µg/L                                                                      10272
# DDT 44' - Eau brute - µg/L                                                                       10269
# Métazachlore - Eau brute - µg/L                                                                  10266
# Endrine - Eau brute - µg/L                                                                       10264
# DDT 24' - Eau brute - µg/L                                                                       10264
# Malathion - Eau brute - µg/L                                                                     10251
# Hexachlorocyclohexane bêta - Eau brute - µg/L                                                    10247
# Pyrimiphos-méthyl - Eau brute - µg/L                                                             10243
# Biphényle - Eau brute - µg/L                                                                     10240
# Epoxiconazole - Eau brute - µg/L                                                                 10237
# Lambda-cyhalothrine - Eau brute - µg/L                                                           10233
# DDE 24' - Eau brute - µg/L                                                                       10228
# Fénitrothion - Eau brute - µg/L                                                                  10228
# DDD 24' - Eau brute - µg/L                                                                       10228
# Name: param_frac_unit, dtype: int64

# %%
prel_count = analyse_df_slim['CdPrelevement'].value_counts()
prel_count
# Out:
# CdPrelevement
# 20220718101831-PC-520929    1688
# 20220729111652-PC-523527    1677
# 20220329143828-PC-510382    1672
# 20220511215956-PC-515850    1672
# 20220210142512-PC-507756    1666
#                             ...
# 20221003161851-PC-528015       1
# 20221003161851-PC-528016       1
# 801751                         1
# 801759                         1
# 801769                         1
# Name: count, Length: 27733, dtype: int64

# %%
sns.displot(prel_count)
sns.displot(prel_count,kind='ecdf')

# %%
import matplotlib.pyplot as plt
sns.displot(prel_count,kind='ecdf')
plt.xscale('log')

# %%
for i in range(10,20):
    print(i,':',prel_count[prel_count>i].shape)
# Out:
# 10 : (23439,)
# 11 : (23415,)
# 12 : (23408,)
# 13 : (23190,)
# 14 : (22967,)
# 15 : (22549,)
# 16 : (22370,)
# 17 : (20229,)
# 18 : (17922,)
# 19 : (16887,)

# %%
analyse_df_slim['CdStationMesureEauxSurface'].unique()
# Out:
# ['01002237', '01002269', '01000457', '01002270', '01002288', ..., '06147660', '06300250', '06700070', '06211700', '06168100']
# Length: 3593
# Categories (3593, str): ['01000455', '01000457', '01002236', '01002237', ..., 'Y5525003', 'Y6705023', 'Y8415003', 'Y9205023']

# %%
df_freq = analyse_df_slim[analyse_df_slim['param_frac_unit'].isin(parameter_frequency.head(15).index)]

df_pivot = pd.pivot_table(data=df_freq,
               values='RsAna',
               index = ['CdStationMesureEauxSurface', 
                        'CdPrelevement',
                        'DatePrel'],
               columns = 'param_frac_unit') \
    .dropna() \
    .reset_index()
df_pivot
# Out:
# param_frac_unit CdStationMesureEauxSurface               CdPrelevement  \
# 0                                 01000455  01000455202208170937222223
# 1                                 01000457  01000457202208171054222223
# 2                                 01002236  01002236202208171120222223
# 3                                 01002237  01002237202201241010222223
# 4                                 01002237  01002237202202211129222223
# ...                                    ...                         ...
# 19344                              N120510    20220309092238-PC-735376
# 19345                              N30-410    20220309092302-PC-735379
# 19346                              N303510    20220309092254-PC-735378
# 19347                              N330510    20220309092310-PC-735380
# 19348                              N71-410    20220309092318-PC-735381
#
# param_frac_unit   DatePrel  \
# 0               2022-08-17
# 1               2022-08-17
# 2               2022-08-17
# 3               2022-01-24
# 4               2022-02-21
# ...                    ...
# 19344           2022-04-12
# 19345           2022-04-06
# 19346           2022-04-06
# 19347           2022-04-04
# 19348           2022-04-05
#
# param_frac_unit  Ammonium - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NH4)/L  \
# 0                                                             0.02
# 1                                                             0.05
# 2                                                             0.02
# 3                                                             0.05
# 4                                                             0.05
# ...                                                            ...
# 19344                                                         0.16
# 19345                                                         0.19
# 19346                                                         0.02
# 19347                                                         0.14
# 19348                                                         0.06
#
# param_frac_unit  Azote Kjeldahl - Eau brute - mg(N)/L  \
# 0                                                0.50
# 1                                                0.50
# 2                                                0.50
# 3                                                0.50
# 4                                                0.50
# ...                                               ...
# 19344                                            1.20
# 19345                                            2.90
# 19346                                            0.50
# 19347                                            0.92
# 19348                                            0.57
#
# param_frac_unit  Carbone Organique - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(C)/L  \
# 0                                                             0.73
# 1                                                             1.30
# 2                                                             1.30
# 3                                                             0.83
# 4                                                             2.30
# ...                                                            ...
# 19344                                                         8.00
# 19345                                                         3.80
# 19346                                                         3.30
# 19347                                                         7.50
# 19348                                                         3.70
#
# param_frac_unit  Conductivité à 25°C - Eau brute - µS/cm  \
# 0                                                  584.0
# 1                                                  561.0
# 2                                                  562.0
# 3                                                  613.0
# 4                                                  588.0
# ...                                                  ...
# 19344                                              230.0
# 19345                                              205.0
# 19346                                              220.0
# 19347                                              238.0
# 19348                                              146.0
#
# param_frac_unit  Demande Biochimique en oxygène en 5 jours (D.B.O.5) - Eau brute - mg(O2)/L  \
# 0                                                              1.5
# 1                                                              1.8
# 2                                                              1.2
# 3                                                              0.9
# 4                                                              0.6
# ...                                                            ...
# 19344                                                          1.3
# 19345                                                          1.0
# 19346                                                          1.9
# 19347                                                          1.5
# 19348                                                          1.7
#
# param_frac_unit  Matières en suspension - Eau brute - mg/L  \
# 0                                                      3.5
# 1                                                      3.7
# 2                                                      2.1
# 3                                                     13.0
# 4                                                     21.0
# ...                                                    ...
# 19344                                                  3.7
# 19345                                                  5.6
# 19346                                                  3.5
# 19347                                                  6.1
# 19348                                                  2.5
#
# param_frac_unit  Nitrates - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO3)/L  \
# 0                                                             22.0
# 1                                                             21.0
# 2                                                             21.0
# 3                                                             22.0
# 4                                                             18.0
# ...                                                            ...
# 19344                                                          6.8
# 19345                                                         20.0
# 19346                                                         22.0
# 19347                                                         12.0
# 19348                                                         17.0
#
# param_frac_unit  Nitrites - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO2)/L  \
# 0                                                             0.05
# 1                                                             0.20
# 2                                                             0.10
# 3                                                             0.05
# 4                                                             0.05
# ...                                                            ...
# 19344                                                         0.08
# 19345                                                         0.11
# 19346                                                         0.08
# 19347                                                         0.11
# 19348                                                         0.06
#
# param_frac_unit  Orthophosphates (PO4) - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(PO4)/L  \
# 0                                                             0.13
# 1                                                             0.21
# 2                                                             0.20
# 3                                                             0.16
# 4                                                             0.81
# ...                                                            ...
# 19344                                                         0.11
# 19345                                                         0.07
# 19346                                                         0.05
# 19347                                                         0.08
# 19348                                                         0.06
#
# param_frac_unit  Oxygène dissous - Eau brute - mg(O2)/L  \
# 0                                                  9.90
# 1                                                  9.40
# 2                                                 11.10
# 3                                                 12.20
# 4                                                 12.00
# ...                                                 ...
# 19344                                             10.57
# 19345                                             10.65
# 19346                                             10.95
# 19347                                             10.42
# 19348                                             11.88
#
# param_frac_unit  Phosphore total - Eau brute - mg(P)/L  \
# 0                                                0.045
# 1                                                0.076
# 2                                                0.068
# 3                                                0.076
# 4                                                0.280
# ...                                                ...
# 19344                                            0.068
# 19345                                            0.028
# 19346                                            0.034
# 19347                                            0.072
# 19348                                            0.027
#
# param_frac_unit  Potentiel en Hydrogène (pH) - Eau brute - unité pH  \
# 0                                                             7.90
# 1                                                             8.10
# 2                                                             8.20
# 3                                                             8.00
# 4                                                             8.10
# ...                                                            ...
# 19344                                                         7.85
# 19345                                                         7.98
# 19346                                                         8.01
# 19347                                                         7.33
# 19348                                                         8.56
#
# param_frac_unit  Taux de saturation en oxygène - Eau brute - %  \
# 0                                                         95.0
# 1                                                         96.0
# 2                                                        114.0
# 3                                                         99.0
# 4                                                        100.0
# ...                                                        ...
# 19344                                                    104.6
# 19345                                                     98.7
# 19346                                                    101.3
# 19347                                                     98.0
# 19348                                                    108.7
#
# param_frac_unit  Température de l'Eau - Eau brute - °C  \
# 0                                              13.2000
# 1                                              16.5000
# 2                                              16.7000
# 3                                               7.3000
# 4                                               7.3000
# ...                                                ...
# 19344                                          14.3000
# 19345                                          11.4000
# 19346                                          11.0600
# 19347                                          12.9344
# 19348                                          11.5000
#
# param_frac_unit  Turbidité Formazine Néphélométrique - Eau brute - NFU
# 0                                                             4.32
# 1                                                             3.00
# 2                                                             1.50
# 3                                                             6.70
# 4                                                            21.00
# ...                                                            ...
# 19344                                                         1.60
# 19345                                                         3.70
# 19346                                                         1.20
# 19347                                                         1.77
# 19348                                                         1.60
#
# [19349 rows x 18 columns]

# %%
print('CdPrelevement',df_pivot['CdPrelevement'].unique().shape)
print('CdStationMesureEauxSurface',df_pivot['CdStationMesureEauxSurface'].unique().shape)
# Out:
# CdPrelevement (20041,)
# CdStationMesureEauxSurface (3045,)

# %%
print('CdPrelevement',             analyse_df_slim['CdPrelevement'].unique().shape)
print('CdStationMesureEauxSurface',analyse_df_slim['CdStationMesureEauxSurface'].unique().shape)

for i in range(5,20):
    df_freq = analyse_df_slim[analyse_df_slim['param_frac_unit'].isin(parameter_frequency.head(i).index)]

    df_pivot = pd.pivot_table(data=df_freq,
                   values='RsAna',
                   index = ['CdStationMesureEauxSurface', 
                            'CdPrelevement',
                            'DatePrel'],
                   columns = 'param_frac_unit') \
        .dropna() \
        .reset_index()
    df_pivot
    print(i)
    print('\t','CdPrelevement',df_pivot['CdPrelevement'].unique().shape)
    print('\t','CdStationMesureEauxSurface',df_pivot['CdStationMesureEauxSurface'].unique().shape)
# Out:
# CdPrelevement (27733,)
# CdStationMesureEauxSurface (3593,)
# 5
# 	 CdPrelevement (25720,)
# 	 CdStationMesureEauxSurface (3494,)
# 6
# 	 CdPrelevement (21375,)
# 	 CdStationMesureEauxSurface (3374,)
# 7
# 	 CdPrelevement (20794,)
# 	 CdStationMesureEauxSurface (3238,)
# 8
# 	 CdPrelevement (20504,)
# 	 CdStationMesureEauxSurface (3171,)
# 9
# 	 CdPrelevement (20041,)
# 	 CdStationMesureEauxSurface (3045,)
# 10
# 	 CdPrelevement (20041,)
# 	 CdStationMesureEauxSurface (3045,)
# 11
# 	 CdPrelevement (20015,)
# 	 CdStationMesureEauxSurface (3034,)
# 12
# 	 CdPrelevement (20015,)
# 	 CdStationMesureEauxSurface (3034,)
# 13
# 	 CdPrelevement (19886,)
# 	 CdStationMesureEauxSurface (2989,)
# 14
# 	 CdPrelevement (19535,)
# 	 CdStationMesureEauxSurface (2919,)
# 15
# 	 CdPrelevement (19349,)
# 	 CdStationMesureEauxSurface (2893,)
# 16
# 	 CdPrelevement (17167,)
# 	 CdStationMesureEauxSurface (2191,)
# 17
# 	 CdPrelevement (13819,)
# 	 CdStationMesureEauxSurface (2122,)
# 18
# 	 CdPrelevement (13612,)
# 	 CdStationMesureEauxSurface (2074,)
# 19
# 	 CdPrelevement (7532,)
# 	 CdStationMesureEauxSurface (1985,)

# %%
#on choisit les 15 paramètres les plus fréquents
df_freq = analyse_df_slim[analyse_df_slim['param_frac_unit'].isin(parameter_frequency.head(15).index)]

df_pivot = pd.pivot_table(data=df_freq,
               values='RsAna',
               index = ['CdStationMesureEauxSurface', 
                        'CdPrelevement',
                        'DatePrel'],
               columns = 'param_frac_unit') \
    .dropna() \
    .reset_index()
df_pivot
# Out:
# param_frac_unit CdStationMesureEauxSurface               CdPrelevement  \
# 0                                 01000455  01000455202208170937222223
# 1                                 01000457  01000457202208171054222223
# 2                                 01002236  01002236202208171120222223
# 3                                 01002237  01002237202201241010222223
# 4                                 01002237  01002237202202211129222223
# ...                                    ...                         ...
# 19344                              N120510    20220309092238-PC-735376
# 19345                              N30-410    20220309092302-PC-735379
# 19346                              N303510    20220309092254-PC-735378
# 19347                              N330510    20220309092310-PC-735380
# 19348                              N71-410    20220309092318-PC-735381
#
# param_frac_unit   DatePrel  \
# 0               2022-08-17
# 1               2022-08-17
# 2               2022-08-17
# 3               2022-01-24
# 4               2022-02-21
# ...                    ...
# 19344           2022-04-12
# 19345           2022-04-06
# 19346           2022-04-06
# 19347           2022-04-04
# 19348           2022-04-05
#
# param_frac_unit  Ammonium - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NH4)/L  \
# 0                                                             0.02
# 1                                                             0.05
# 2                                                             0.02
# 3                                                             0.05
# 4                                                             0.05
# ...                                                            ...
# 19344                                                         0.16
# 19345                                                         0.19
# 19346                                                         0.02
# 19347                                                         0.14
# 19348                                                         0.06
#
# param_frac_unit  Azote Kjeldahl - Eau brute - mg(N)/L  \
# 0                                                0.50
# 1                                                0.50
# 2                                                0.50
# 3                                                0.50
# 4                                                0.50
# ...                                               ...
# 19344                                            1.20
# 19345                                            2.90
# 19346                                            0.50
# 19347                                            0.92
# 19348                                            0.57
#
# param_frac_unit  Carbone Organique - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(C)/L  \
# 0                                                             0.73
# 1                                                             1.30
# 2                                                             1.30
# 3                                                             0.83
# 4                                                             2.30
# ...                                                            ...
# 19344                                                         8.00
# 19345                                                         3.80
# 19346                                                         3.30
# 19347                                                         7.50
# 19348                                                         3.70
#
# param_frac_unit  Conductivité à 25°C - Eau brute - µS/cm  \
# 0                                                  584.0
# 1                                                  561.0
# 2                                                  562.0
# 3                                                  613.0
# 4                                                  588.0
# ...                                                  ...
# 19344                                              230.0
# 19345                                              205.0
# 19346                                              220.0
# 19347                                              238.0
# 19348                                              146.0
#
# param_frac_unit  Demande Biochimique en oxygène en 5 jours (D.B.O.5) - Eau brute - mg(O2)/L  \
# 0                                                              1.5
# 1                                                              1.8
# 2                                                              1.2
# 3                                                              0.9
# 4                                                              0.6
# ...                                                            ...
# 19344                                                          1.3
# 19345                                                          1.0
# 19346                                                          1.9
# 19347                                                          1.5
# 19348                                                          1.7
#
# param_frac_unit  Matières en suspension - Eau brute - mg/L  \
# 0                                                      3.5
# 1                                                      3.7
# 2                                                      2.1
# 3                                                     13.0
# 4                                                     21.0
# ...                                                    ...
# 19344                                                  3.7
# 19345                                                  5.6
# 19346                                                  3.5
# 19347                                                  6.1
# 19348                                                  2.5
#
# param_frac_unit  Nitrates - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO3)/L  \
# 0                                                             22.0
# 1                                                             21.0
# 2                                                             21.0
# 3                                                             22.0
# 4                                                             18.0
# ...                                                            ...
# 19344                                                          6.8
# 19345                                                         20.0
# 19346                                                         22.0
# 19347                                                         12.0
# 19348                                                         17.0
#
# param_frac_unit  Nitrites - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(NO2)/L  \
# 0                                                             0.05
# 1                                                             0.20
# 2                                                             0.10
# 3                                                             0.05
# 4                                                             0.05
# ...                                                            ...
# 19344                                                         0.08
# 19345                                                         0.11
# 19346                                                         0.08
# 19347                                                         0.11
# 19348                                                         0.06
#
# param_frac_unit  Orthophosphates (PO4) - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(PO4)/L  \
# 0                                                             0.13
# 1                                                             0.21
# 2                                                             0.20
# 3                                                             0.16
# 4                                                             0.81
# ...                                                            ...
# 19344                                                         0.11
# 19345                                                         0.07
# 19346                                                         0.05
# 19347                                                         0.08
# 19348                                                         0.06
#
# param_frac_unit  Oxygène dissous - Eau brute - mg(O2)/L  \
# 0                                                  9.90
# 1                                                  9.40
# 2                                                 11.10
# 3                                                 12.20
# 4                                                 12.00
# ...                                                 ...
# 19344                                             10.57
# 19345                                             10.65
# 19346                                             10.95
# 19347                                             10.42
# 19348                                             11.88
#
# param_frac_unit  Phosphore total - Eau brute - mg(P)/L  \
# 0                                                0.045
# 1                                                0.076
# 2                                                0.068
# 3                                                0.076
# 4                                                0.280
# ...                                                ...
# 19344                                            0.068
# 19345                                            0.028
# 19346                                            0.034
# 19347                                            0.072
# 19348                                            0.027
#
# param_frac_unit  Potentiel en Hydrogène (pH) - Eau brute - unité pH  \
# 0                                                             7.90
# 1                                                             8.10
# 2                                                             8.20
# 3                                                             8.00
# 4                                                             8.10
# ...                                                            ...
# 19344                                                         7.85
# 19345                                                         7.98
# 19346                                                         8.01
# 19347                                                         7.33
# 19348                                                         8.56
#
# param_frac_unit  Taux de saturation en oxygène - Eau brute - %  \
# 0                                                         95.0
# 1                                                         96.0
# 2                                                        114.0
# 3                                                         99.0
# 4                                                        100.0
# ...                                                        ...
# 19344                                                    104.6
# 19345                                                     98.7
# 19346                                                    101.3
# 19347                                                     98.0
# 19348                                                    108.7
#
# param_frac_unit  Température de l'Eau - Eau brute - °C  \
# 0                                              13.2000
# 1                                              16.5000
# 2                                              16.7000
# 3                                               7.3000
# 4                                               7.3000
# ...                                                ...
# 19344                                          14.3000
# 19345                                          11.4000
# 19346                                          11.0600
# 19347                                          12.9344
# 19348                                          11.5000
#
# param_frac_unit  Turbidité Formazine Néphélométrique - Eau brute - NFU
# 0                                                             4.32
# 1                                                             3.00
# 2                                                             1.50
# 3                                                             6.70
# 4                                                            21.00
# ...                                                            ...
# 19344                                                         1.60
# 19345                                                         3.70
# 19346                                                         1.20
# 19347                                                         1.77
# 19348                                                         1.60
#
# [19349 rows x 18 columns]

# %% [markdown]
# ### correlation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
sns.heatmap(df_pivot.iloc[:,4:].corr(),
            vmin=-1,
            vmax=1,
            annot=True,
            cmap='coolwarm')
# Out:
# <Axes: xlabel='param_frac_unit', ylabel='param_frac_unit'>

# %%
param_alteration = analyse_merged[['param_frac_unit','nom.1']].drop_duplicates().set_index('param_frac_unit')
param_alteration.index.unique()
# Out:
# CategoricalIndex(['Turbidité Formazine Néphélométrique - Eau brute - NFU',
#                   'Température de l'Eau - Eau brute - °C',
#                   'Potentiel en Hydrogène (pH) - Eau brute - unité pH',
#                   'Conductivité à 25°C - Eau brute - µS/cm',
#                   'Oxygène dissous - Eau brute - mg(O2)/L',
#                   'Taux de saturation en oxygène - Eau brute - %',
#                   'Matières en suspension - Eau brute - mg/L',
#                   'Demande Biochimique en oxygène en 5 jours (D.B.O.5) - Eau brute - mg(O2)/L',
#                   'Demande Chimique en Oxygène (DCO) - Eau brute - mg(O2)/L',
#                   'Azote Kjeldahl - Eau brute - mg(N)/L',
#                   ...
#                   'Xylène-méta - Sédiments bruts - µg/(kg MS)',
#                   'Xylène-para - Sédiments bruts - µg/(kg MS)',
#                   '2,4-D-ester - Eau brute - µg/L',
#                   'PCB 101 - Matière sèche de particules < 2 mm - µg/kg',
#                   'PCB 118 - Matière sèche de particules < 2 mm - µg/kg',
#                   'PCB 138 - Matière sèche de particules < 2 mm - µg/kg',
#                   'PCB 153 - Matière sèche de particules < 2 mm - µg/kg',
#                   'PCB 180 - Matière sèche de particules < 2 mm - µg/kg',
#                   'PCB 28 - Matière sèche de particules < 2 mm - µg/kg',
#                   'PCB 52 - Matière sèche de particules < 2 mm - µg/kg'],
#                  categories=['1,1,1,2-Tetrachloropropane - Particule < 2 mm..., '1,1,1,2-Tetrachloropropane - Particule < 2 mm..., '1,1,1,3-Tetrachloropropane - Particule < 2 mm..., '1,1,1,3-Tetrachloropropane - Particule < 2 mm..., ..., 'tétrabromodiphényl éther (congénère 47) - Mat..., 'tétrabromodiphényl éther (congénère 47) - Par..., 'tétrabromodiphényl éther (congénère 47) - Par..., 'tétrabromodiphényl éther (congénère 47) - Pha...], ordered=False, dtype='category', name='param_frac_unit', length=872)

# %%
df_corr = df_pivot.iloc[:,4:].corr()
for x in df_corr.index:
    for y in df_corr.columns:
        if 1>abs(df_corr.loc[x,y])>0.5:
            print('correlation:',df_corr.loc[x,y])
            print(x,list(param_alteration.loc[[x],'nom.1'].values))
            print(y,list(param_alteration.loc[[y],'nom.1'].values))
            print()
# Out:
# correlation: 0.7570169945796988
# Matières en suspension - Eau brute - mg/L ['PAES']
# Turbidité Formazine Néphélométrique - Eau brute - NFU ['PAES']
#
# correlation: 0.9609458232123879
# Orthophosphates (PO4) - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(PO4)/L ['NUTRI', 'PHOS']
# Phosphore total - Eau brute - mg(P)/L ['NUTRI', 'PHOS']
#
# correlation: 0.7106255296407127
# Oxygène dissous - Eau brute - mg(O2)/L ['BILO2', 'MOOX']
# Taux de saturation en oxygène - Eau brute - % ['BILO2', 'EPRV', 'MOOX']
#
# correlation: -0.6211078311244305
# Oxygène dissous - Eau brute - mg(O2)/L ['BILO2', 'MOOX']
# Température de l'Eau - Eau brute - °C ['TEMP']
#
# correlation: 0.9609458232123879
# Phosphore total - Eau brute - mg(P)/L ['NUTRI', 'PHOS']
# Orthophosphates (PO4) - Phase aqueuse de l'eau (filtrée, centrifugée...) - mg(PO4)/L ['NUTRI', 'PHOS']
#
# correlation: 0.7106255296407127
# Taux de saturation en oxygène - Eau brute - % ['BILO2', 'EPRV', 'MOOX']
# Oxygène dissous - Eau brute - mg(O2)/L ['BILO2', 'MOOX']
#
# correlation: -0.6211078311244305
# Température de l'Eau - Eau brute - °C ['TEMP']
# Oxygène dissous - Eau brute - mg(O2)/L ['BILO2', 'MOOX']
#
# correlation: 0.7570169945796988
# Turbidité Formazine Néphélométrique - Eau brute - NFU ['PAES']
# Matières en suspension - Eau brute - mg/L ['PAES']

# %%
import pandas as pd
import geopandas as gpd
import shapely.geometry as geom
import os



df_stations = pd.read_csv("stations.csv.zst",sep=';',escapechar = '\\')
# Out:
# /tmp/ipykernel_3819/1566283560.py:8: DtypeWarning: Columns (0: CdEuMasseDEau, 1: NomMasseDEau, 2: CdEuSsBassinDCEAdmin, 3: NomSsBassinDCEAdmin, 4: CdBassinDCE, 5: CdEuBassinDCE, 6: NomEuBassinDCE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_stations = pd.read_csv("stations.csv.zst",sep=';',escapechar = '\\')

# %%
crs_lambert = 'PROJCS["RGF_1993_Lambert_93",GEOGCS["GCS_RGF_1993",DATUM["D_RGF_1993",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Lambert_Conformal_Conic"],PARAMETER["False_Easting",700000.0],PARAMETER["False_Northing",6600000.0],PARAMETER["Central_Meridian",3.0],PARAMETER["Standard_Parallel_1",49.0],PARAMETER["Standard_Parallel_2",44.0],PARAMETER["Latitude_Of_Origin",46.5],UNIT["Meter",1.0]]'
x_col = 'CoordXStationMesureEauxSurface'
y_col = 'CoordYStationMesureEauxSurface'

carto = gpd.GeoDataFrame(df_stations,crs=crs_lambert ,
                        geometry = gpd.GeoSeries(df_stations.agg(lambda x:geom.Point(x.loc[x_col],x.loc[y_col])  ,axis=1)))

# %%
carto
# Out:
#       CdStationMesureEauxSurface      LbStationMesureEauxSurface  \
# 0                       H4389203                   Lac du Mesnil
# 1                       V03-4003                           LEMAN
# 2                       01083000  LE CANAL DE LENS À HARNES (62)
# 3                       02054100           LA MOSELLE À CHAVELOT
# 4                       02057503           LE REVAU À VAUDEVILLE
# ...                          ...                             ...
# 22105                   11000018          Batrini  intermédiaire
# 22106                   11000019                   Chririni aval
# 22107                   11000020                   Gouloué amont
# 22108                   11000021                   Djalimou aval
# 22109                   11000024                    Gouloué aval
#
#        DurStationMesureEauxSurface  CoordXStationMesureEauxSurface  \
# 0                              NaN                       572420.00
# 1                              NaN                       977500.00
# 2                              NaN                       694108.84
# 3                              NaN                       955373.00
# 4                              NaN                       935577.00
# ...                            ...                             ...
# 22105                          NaN                       512127.00
# 22106                          NaN                       511348.00
# 22107                          NaN                       520684.00
# 22108                          NaN                       512401.00
# 22109                          NaN                       522210.00
#
#        CoordYStationMesureEauxSurface  CdProjStationMesureEauxSurface  \
# 0                          6911609.99                              26
# 1                          6600000.00                              26
# 2                          7038840.78                              26
# 3                          6798229.00                              26
# 4                          6822741.00                              26
# ...                               ...                             ...
# 22105                      8589390.00                              41
# 22106                      8587446.00                              41
# 22107                      8585917.00                              41
# 22108                      8567948.00                              41
# 22109                      8585007.00                              41
#
#         LibelleProjection CodeCommune      LbCommune CodeDepartement  ...  \
# 0      RGF93 / Lambert 93         NaN            NaN             NaN  ...
# 1      RGF93 / Lambert 93         NaN            NaN             NaN  ...
# 2      RGF93 / Lambert 93       62413         Harnes              62  ...
# 3      RGF93 / Lambert 93       88099       Chavelot              88  ...
# 4      RGF93 / Lambert 93       54553     Vaudeville              54  ...
# ...                   ...         ...            ...             ...  ...
# 22105      RGM04 / UTM 38       97613  M'Tsangamouji             976  ...
# 22106      RGM04 / UTM 38       97617       Tsingoni             976  ...
# 22107      RGM04 / UTM 38       97611      Mamoudzou             976  ...
# 22108      RGM04 / UTM 38       97609      Kani-Kéli             976  ...
# 22109      RGM04 / UTM 38       97611      Mamoudzou             976  ...
#
#       FinaliteStationMesureEauxSurface    LocPreciseStationMesureEauxSurface  \
# 0                                  NaN                         Non renseigné
# 1                                  NaN                           Non précisé
# 2                                  NaN                         PONT DU CD 39
# 3                                  NaN                 LA MOSELLE À CHAVELOT
# 4                                  NaN                 LE REVAU À VAUDEVILLE
# ...                                ...                                   ...
# 22105                              2,2  Intermédiaire de la rivière Batrini
# 22106                              2,2            Aval de la rivière Chirini
# 22107                              2,2           Amont de la rivière Gouloué
# 22108                              2,2           Aval de la rivière Djalimou
# 22109                              2,2            Aval de la rivière Gouloué
#
#       CodeNatureStationMesureEauxSurface  \
# 0                                      M
# 1                                      M
# 2                                      M
# 3                                      0
# 4                                      0
# ...                                  ...
# 22105                                  0
# 22106                                  0
# 22107                                  0
# 22108                                  0
# 22109                                  0
#
#       LibelleNatureStationMesureEauxSurface AltitudePointCaracteritisque  \
# 0                Station de mesure Manuelle                         0.00
# 1                Station de mesure Manuelle                         0.00
# 2                Station de mesure Manuelle                        29.47
# 3             Nature de la station inconnue                       310.00
# 4             Nature de la station inconnue                       244.00
# ...                                     ...                          ...
# 22105         Nature de la station inconnue                          NaN
# 22106         Nature de la station inconnue                          NaN
# 22107         Nature de la station inconnue                          NaN
# 22108         Nature de la station inconnue                          NaN
# 22109         Nature de la station inconnue                          NaN
#
#       PkPointTronconEntiteHydroPrincipale PremierMoisAnneeEtiage  \
# 0                                     NaN                    NaN
# 1                                     NaN                    NaN
# 2                                  996.55                    6.0
# 3                                     NaN                    NaN
# 4                                     NaN                    NaN
# ...                                   ...                    ...
# 22105                                 NaN                    NaN
# 22106                                 NaN                    NaN
# 22107                                 NaN                    NaN
# 22108                                 NaN                    NaN
# 22109                                 NaN                    NaN
#
#       SuperficieBassinVersantReel SuperficieBassinVersantTopo  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                     1257.14
# 4                             NaN                         NaN
# ...                           ...                         ...
# 22105                         NaN                         NaN
# 22106                         NaN                         NaN
# 22107                         NaN                         NaN
# 22108                         NaN                         NaN
# 22109                         NaN                         NaN
#
#                            geometry
# 0         POINT (572420 6911609.99)
# 1            POINT (977500 6600000)
# 2      POINT (694108.84 7038840.78)
# 3            POINT (955373 6798229)
# 4            POINT (935577 6822741)
# ...                             ...
# 22105        POINT (512127 8589390)
# 22106        POINT (511348 8587446)
# 22107        POINT (520684 8585917)
# 22108        POINT (512401 8567948)
# 22109        POINT (522210 8585007)
#
# [22110 rows x 40 columns]
